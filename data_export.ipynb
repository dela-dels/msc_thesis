# %%
import pandas as pd

# %%
df = pd.read_csv('databanks_export_monthly.csv')

# %%
df.head()
# Out:
#              Name of Series   Jan-06     Feb-06     Mar-06     Apr-06  \
# 0  Monetary Policy Rate (%)  14.5000  14.500000  14.500000  14.500000
# 1            Food Inflation  11.6900  10.730000  10.660000  10.550000
# 2        Headline Inflation  12.7600  12.270000  11.280000  11.210000
# 3        Non-Food Inflation  13.6000  13.460000  11.760000  11.720000
# 4         USD Exchange Rate   0.9083   0.909341   0.910591   0.910991
#
#       May-06    Jun-06     Jul-06     Aug-06     Sep-06  ...  Nov-24  Dec-24  \
# 0  14.500000  14.50000  14.500000  14.500000  14.500000  ...   27.00   27.00
# 1  11.430000  10.67000  11.840000  10.770000   8.730000  ...   25.94   27.77
# 2  11.750000  11.39000  12.910000  12.560000  11.670000  ...   23.03   23.82
# 3  11.990000  11.95000  13.730000  13.930000  13.940000  ...   20.66   20.32
# 4   0.912986   0.91615   0.916618   0.919932   0.920386  ...   15.27   14.70
#
#     Jan-25  Feb-25  Mar-25  Apr-25  May-25  Jun-25  Jul-25  Aug-25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Columns: 237 entries, Name of Series to Aug-25
# dtypes: float64(236), object(1)
# memory usage: 24.2+ KB

# %%
df_wide = df.set_index('Name of Series').T

# %%
df_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 236 entries, Jan-06 to Aug-25
# Data columns (total 13 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Monetary Policy Rate (%)                           236 non-null    float64
#  1   Food Inflation                                     236 non-null    float64
#  2   Headline Inflation                                 236 non-null    float64
#  3   Non-Food Inflation                                 236 non-null    float64
#  4   USD Exchange Rate                                  236 non-null    float64
#  5   Brent Crude Oil Price (International indicative))  236 non-null    float64
#  6   Cocoa Price (International indicative)             236 non-null    float64
#  7   Gold Price (International indicative)              236 non-null    float64
# ...

# %%
# Convert column names of df_wide to datetime in the format 'mm-dd-yyyy'
df_wide.index = pd.to_datetime(df_wide.index, format='%b-%y')
df_wide.index = df_wide.index.strftime('%m-%d-%Y')

# %%
df_wide
# Out:
# Name of Series  Monetary Policy Rate (%)  Food Inflation  Headline Inflation  \
# 01-01-2006                          14.5           11.69               12.76
# 02-01-2006                          14.5           10.73               12.27
# 03-01-2006                          14.5           10.66               11.28
# 04-01-2006                          14.5           10.55               11.21
# 05-01-2006                          14.5           11.43               11.75
# ...                                  ...             ...                 ...
# 04-01-2025                          28.0           25.02               21.24
# 05-01-2025                          28.0           22.83               18.38
# 06-01-2025                          28.0           16.31               13.67
# 07-01-2025                          25.0           15.14               12.14
# 08-01-2025                          25.0           14.80               11.48
#
# ...

# %%
df_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 236 entries, 01-01-2006 to 08-01-2025
# Data columns (total 13 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Monetary Policy Rate (%)                           236 non-null    float64
#  1   Food Inflation                                     236 non-null    float64
#  2   Headline Inflation                                 236 non-null    float64
#  3   Non-Food Inflation                                 236 non-null    float64
#  4   USD Exchange Rate                                  236 non-null    float64
#  5   Brent Crude Oil Price (International indicative))  236 non-null    float64
#  6   Cocoa Price (International indicative)             236 non-null    float64
#  7   Gold Price (International indicative)              236 non-null    float64
# ...
